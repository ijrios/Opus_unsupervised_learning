# %%
! git clone https://github.com/ijrios/databases_opus_quattour.git
# Out:
# fatal: destination path 'databases_opus_quattour' already exists and is not an empty directory.

# %%
import scipy.io as sio
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Primer base de datos

# %%
data=sio.loadmat('/content/databases_opus_quattour/Aggregation.mat')
dato = data['Aggregation']

# %% [markdown]
# ### Implementación del Kmeans para la primera base de datos

# %%
# Por defecto usa la distancia euclidiana
km = KMeans(
    n_clusters=3, init='random',
    n_init=10, random_state=0
)

y_km = km.fit_predict(dato)
# plot the clusters
plt.scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=y_km)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato)
    centers = clusterer.cluster_centers_

    score = silhouette_score (dato, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))
# Out:
# For n_clusters =2 silhouette score is 0.4514922274505363
# For n_clusters =3 silhouette score is 0.5267866780954938
# For n_clusters =4 silhouette score is 0.5259754115311497
# For n_clusters =5 silhouette score is 0.4996440610783604
# For n_clusters =6 silhouette score is 0.5176252024691022
# For n_clusters =7 silhouette score is 0.4937493077695345
# For n_clusters =8 silhouette score is 0.4643293908120415
# For n_clusters =9 silhouette score is 0.4855582681382204

# %%
# 2 clusters
clusterer_2 = KMeans(n_clusters=2,n_init=10)
preds_kmeans_2 = clusterer_2.fit_predict(dato)
# 3 clusters
clusterer_3 = KMeans(n_clusters=3,n_init=10)
preds_kmeans_3 = clusterer_3.fit_predict(dato)
# 4 clusters
clusterer_4 = KMeans(n_clusters=4,n_init=10)
preds_kmeans_4 = clusterer_4.fit_predict(dato)
# 5 clusters
clusterer_5 = KMeans(n_clusters=5,n_init=10)
preds_kmeans_5 = clusterer_5.fit_predict(dato)
# 6 clusters
clusterer_6 = KMeans(n_clusters=6,n_init=10)
preds_kmeans_6 = clusterer_6.fit_predict(dato)
# 7 clusters
clusterer_7 = KMeans(n_clusters=7,n_init=10)
preds_kmeans_7 = clusterer_7.fit_predict(dato)
# 8 clusters
clusterer_8 = KMeans(n_clusters=8,n_init=10)
preds_kmeans_8 = clusterer_8.fit_predict(dato)
# 9 clusters
clusterer_9 = KMeans(n_clusters=9,n_init=10)
preds_kmeans_9 = clusterer_9.fit_predict(dato)

# %% [markdown]
# ### Implementación del Spectral Clustering para la primera base de datos

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# create spectral clustering object
spectral = SpectralClustering(n_clusters=5, affinity='rbf', gamma=1)

# fit and predict clusters
labels = spectral.fit_predict(dato)

# plot the clusters
plt.scatter(dato[:, 0], dato[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = SpectralClustering(n_clusters=n_clusters,assign_labels='discretize')
    preds = clusterer.fit_predict(dato)
    centers = clusterer.labels_

    score = silhouette_score (dato, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
# 2 clusters
SC_clusterer_2 = SpectralClustering(n_clusters=2,assign_labels='discretize')
preds_SpectralClustering_2 = SC_clusterer_2.fit_predict(dato)
# 3 clusters
SC_clusterer_3 = SpectralClustering(n_clusters=3,assign_labels='discretize')
preds_SpectralClustering_3 = SC_clusterer_3.fit_predict(dato)
# 4 clusters
SC_clusterer_4 = SpectralClustering(n_clusters=4,assign_labels='discretize')
preds_SpectralClustering_4 = SC_clusterer_4.fit_predict(dato)
# 5 clusters
SC_clusterer_5 = SpectralClustering(n_clusters=5,assign_labels='discretize')
preds_SpectralClustering_5 = SC_clusterer_5.fit_predict(dato)
# 6 clusters
SC_clusterer_6 = SpectralClustering(n_clusters=6,assign_labels='discretize')
preds_SpectralClustering_6 = SC_clusterer_6.fit_predict(dato)
# 7 clusters
SC_clusterer_7 = SpectralClustering(n_clusters=7,assign_labels='discretize')
preds_SpectralClustering_7 = SC_clusterer_7.fit_predict(dato)
# 8 clusters
SC_clusterer_8 = SpectralClustering(n_clusters=8,assign_labels='discretize')
preds_SpectralClustering_8 = SC_clusterer_8.fit_predict(dato)
# 9 clusters
SC_clusterer_9 = SpectralClustering(n_clusters=9,assign_labels='discretize')
preds_SpectralClustering_9 = SC_clusterer_9.fit_predict(dato)

# %% [markdown]
# ### Implementación del DBSCAN para la primera base de datos

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto DBSCAN
dbscan = DBSCAN(eps=3, min_samples=2)

# Ajustar modelo DBSCAN a los datos
dbscan.fit(dato)

# Obtener las etiquetas de los clusters
labels = dbscan.labels_

# plot the clusters
plt.scatter(dato[:, 0], dato[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = DBSCAN(eps=3, min_samples=n_clusters)
    preds = clusterer.fit_predict(dato)
    centers = clusterer.labels_

    score = silhouette_score (dato, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = DBSCAN(eps=3, min_samples=8)
preds = clusterer.fit_predict(dato)

# %% [markdown]
# ### Implementación del Gaussian Mixture Models para la primera base de datos

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto GaussianMixture
gmm = GaussianMixture(n_components=3)

# Ajustar modelo GaussianMixture a los datos
gmm.fit(dato)

# Obtener las etiquetas de los clusters
labels = gmm.predict(dato)

# plot the clusters
plt.scatter(dato[:, 0], dato[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = GaussianMixture(n_components=n_clusters)
    preds = clusterer.fit_predict(dato)
    centers = gmm.predict(dato)


    score = silhouette_score (dato, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = GaussianMixture(n_components=6)
preds = clusterer.fit_predict(dato)

# %% [markdown]
# ## Graficas de la primera base de datos

# %%
fig, ax = plt.subplots(8,4) 
fig.set_size_inches(15,20)
ax[0,0].title.set_text("Kmeans")
ax[0,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_2)
ax[1,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_3)
ax[2,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_4)
ax[3,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_5)
ax[4,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_6)
ax[5,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_7)
ax[6,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_8)
ax[7,0].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_kmeans_9)
ax[0,0].title.set_text("Spectral Clustering")
ax[0,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_2)
ax[1,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_3)
ax[2,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_4)
ax[3,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_5)
ax[4,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_6)
ax[5,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_7)
ax[6,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_8)
ax[7,1].scatter(dato[:, 0], dato[:, 1], cmap='viridis',c=preds_SpectralClustering_9)

# %% [markdown]
# # Segunda base de datos

# %%
data_duo=sio.loadmat('/content/databases_opus_quattour/Compound.mat')
dato_duo = data_duo['Compound']

# %% [markdown]
# ### Implementación del Kmeans para la segunda base de datos

# %%
# Por defecto usa la distancia euclidiana
km = KMeans(
    n_clusters=3, init='random',
    n_init=10, random_state=0
)
y_km = km.fit_predict(dato_duo)
# plot the clusters
plt.scatter(dato_duo[:, 0], dato_duo[:, 1], cmap='viridis',c=y_km)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato_duo)
    centers = clusterer.cluster_centers_

    score = silhouette_score (dato_duo, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
# 2 clusters
clusterer_2 = KMeans(n_clusters=2,n_init=10)
preds_kmeans_2 = clusterer_2.fit_predict(dato_duo)
# 3 clusters
clusterer_3 = KMeans(n_clusters=3,n_init=10)
preds_kmeans_3 = clusterer_3.fit_predict(dato_duo)
# 4 clusters
clusterer_4 = KMeans(n_clusters=4,n_init=10)
preds_kmeans_4 = clusterer_4.fit_predict(dato_duo)
# 5 clusters
clusterer_5 = KMeans(n_clusters=5,n_init=10)
preds_kmeans_5 = clusterer_5.fit_predict(dato_duo)
# 6 clusters
clusterer_6 = KMeans(n_clusters=6,n_init=10)
preds_kmeans_6 = clusterer_6.fit_predict(dato_duo)
# 7 clusters
clusterer_7 = KMeans(n_clusters=7,n_init=10)
preds_kmeans_7 = clusterer_7.fit_predict(dato_duo)
# 8 clusters
clusterer_8 = KMeans(n_clusters=8,n_init=10)
preds_kmeans_8 = clusterer_8.fit_predict(dato_duo)
# 9 clusters
clusterer_9 = KMeans(n_clusters=9,n_init=10)
preds_kmeans_9 = clusterer_9.fit_predict(dato_duo)

# %% [markdown]
# ### Implementación del Spectral Clustering para la segunda base de datos

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# create spectral clustering object
spectral = SpectralClustering(n_clusters=5, affinity='rbf', gamma=1)

# fit and predict clusters
labels = spectral.fit_predict(dato_duo)

# plot the clusters
plt.scatter(dato_duo[:, 0], dato_duo[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = SpectralClustering(n_clusters=n_clusters,assign_labels='discretize')
    preds = clusterer.fit_predict(dato_duo)
    centers = clusterer.labels_

    score = silhouette_score (dato_duo, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = SpectralClustering(n_clusters=2,assign_labels='discretize')
preds = clusterer.fit_predict(dato_duo)

# %% [markdown]
# ### Implementación del DBSCAN para la segunda base de datos

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)

# Ajustar modelo DBSCAN a los datos
dbscan.fit(dato_duo)

# Obtener las etiquetas de los clusters
labels = dbscan.labels_

# plot the clusters
plt.scatter(dato_duo[:, 0], dato_duo[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = DBSCAN(eps=3, min_samples=n_clusters)
    preds = clusterer.fit_predict(dato_duo)
    centers = clusterer.labels_

    score = silhouette_score (dato_duo, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = DBSCAN(eps=3, min_samples=n_clusters)
preds = clusterer.fit_predict(dato)

# %% [markdown]
# ### Implementación del Gaussian Mixture Models para la segunda base de datos

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto GaussianMixture
gmm = GaussianMixture(n_components=3)

# Ajustar modelo GaussianMixture a los datos
gmm.fit(dato_duo)

# Obtener las etiquetas de los clusters
labels = gmm.predict(dato)

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = GaussianMixture(n_components=n_clusters)
    preds = clusterer.fit_predict(dato_duo)
    centers = gmm.predict(dato_duo)

    score = silhouette_score (dato_duo, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = GaussianMixture(n_components=5)
preds = clusterer.fit_predict(dato_duo)

# %% [markdown]
# # Tercera base de datos

# %%
data_tris=sio.loadmat('/content/databases_opus_quattour/flame.mat')
dato_tris = data_tris['flame']

# %% [markdown]
# ### Implementación del Kmeans para la tercera base de datos

# %%
# Por defecto usa la distancia euclidiana
km = KMeans(
    n_clusters=3, init='random',
    n_init=10, random_state=0
)
y_km = km.fit_predict(dato_tris)
# plot the clusters
plt.scatter(dato_tris[:, 0], dato_tris[:, 1], cmap='viridis', c=y_km)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato_tris)
    centers = clusterer.cluster_centers_

    score = silhouette_score (dato_tris, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
# 2 clusters
clusterer_2 = KMeans(n_clusters=2,n_init=10)
preds_kmeans_2 = clusterer_2.fit_predict(dato_tris)
# 3 clusters
clusterer_3 = KMeans(n_clusters=3,n_init=10)
preds_kmeans_3 = clusterer_3.fit_predict(dato_tris)
# 4 clusters
clusterer_4 = KMeans(n_clusters=4,n_init=10)
preds_kmeans_4 = clusterer_4.fit_predict(dato_tris)
# 5 clusters
clusterer_5 = KMeans(n_clusters=5,n_init=10)
preds_kmeans_5 = clusterer_5.fit_predict(dato_tris)
# 6 clusters
clusterer_6 = KMeans(n_clusters=6,n_init=10)
preds_kmeans_6 = clusterer_6.fit_predict(dato_tris)
# 7 clusters
clusterer_7 = KMeans(n_clusters=7,n_init=10)
preds_kmeans_7 = clusterer_7.fit_predict(dato_tris)
# 8 clusters
clusterer_8 = KMeans(n_clusters=8,n_init=10)
preds_kmeans_8 = clusterer_8.fit_predict(dato_tris)
# 9 clusters
clusterer_9 = KMeans(n_clusters=9,n_init=10)
preds_kmeans_9 = clusterer_9.fit_predict(dato_tris)

# %% [markdown]
# ### Implementación del Spectral Clustering para la tercera base de datos

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# create spectral clustering object
spectral = SpectralClustering(n_clusters=5, affinity='rbf', gamma=1)

# fit and predict clusters
labels = spectral.fit_predict(dato_tris)

# plot the clusters
plt.scatter(dato_tris[:, 0], dato_tris[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = SpectralClustering(n_clusters=n_clusters,assign_labels='discretize')
    preds = clusterer.fit_predict(dato_tris)
    centers = clusterer.labels_

    score = silhouette_score (dato_tris, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = SpectralClustering(n_clusters=5,assign_labels='discretize')
preds = clusterer.fit_predict(dato_tris)

# %% [markdown]
# ### Implementación del DBSCAN para la tercera base de datos

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto DBSCAN
dbscan = DBSCAN(eps=1, min_samples=3)

# Ajustar modelo DBSCAN a los datos
dbscan.fit(dato_tris)

# Obtener las etiquetas de los clusters
labels = dbscan.labels_

# plot the clusters
plt.scatter(dato_tris[:, 0], dato_tris[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 8))

for n_clusters in list_k:
    clusterer = DBSCAN(eps=1, min_samples=n_clusters)
    preds = clusterer.fit_predict(dato_tris)
    centers = clusterer.labels_

    score = silhouette_score (dato_tris, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %% [markdown]
# ### Implementación del Gaussian Mixture Models para la tercera base de datos

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto GaussianMixture
gmm = GaussianMixture(n_components=2)

# Ajustar modelo GaussianMixture a los datos
gmm.fit(dato_tris)

# Obtener las etiquetas de los clusters
labels = gmm.predict(dato_tris)

# plot the clusters
plt.scatter(dato_tris[:, 0], dato_tris[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = GaussianMixture(n_components=n_clusters)
    preds = clusterer.fit_predict(dato_tris)
    centers = gmm.predict(dato_tris)

    score = silhouette_score (dato_tris, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = GaussianMixture(n_components=5)
preds = clusterer.fit_predict(dato_tris)

# %% [markdown]
# # Cuarta base de datos

# %%
data_quattour=sio.loadmat('/content/databases_opus_quattour/pathbased.mat')
dato_quattour = data_quattour['pathbased']

# %% [markdown]
# ### Implementación del Kmeans para la cuarta base de datos

# %%
# Por defecto usa la distancia euclidiana
km = KMeans(
    n_clusters=3, init='random',
    n_init=10, random_state=0
)
y_km = km.fit_predict(dato_quattour)
# plot the clusters
plt.scatter(dato_quattour[:, 0], dato_quattour[:, 1], cmap='viridis', c=y_km)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato_quattour)
    centers = clusterer.cluster_centers_

    score = silhouette_score (dato_quattour, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
# 2 clusters
clusterer_2 = KMeans(n_clusters=2,n_init=10)
preds_kmeans_2 = clusterer_2.fit_predict(dato_quattour)
# 3 clusters
clusterer_3 = KMeans(n_clusters=3,n_init=10)
preds_kmeans_3 = clusterer_3.fit_predict(dato_quattour)
# 4 clusters
clusterer_4 = KMeans(n_clusters=4,n_init=10)
preds_kmeans_4 = clusterer_4.fit_predict(dato_quattour)
# 5 clusters
clusterer_5 = KMeans(n_clusters=5,n_init=10)
preds_kmeans_5 = clusterer_5.fit_predict(dato_quattour)
# 6 clusters
clusterer_6 = KMeans(n_clusters=6,n_init=10)
preds_kmeans_6 = clusterer_6.fit_predict(dato_quattour)
# 7 clusters
clusterer_7 = KMeans(n_clusters=7,n_init=10)
preds_kmeans_7 = clusterer_7.fit_predict(dato_quattour)
# 8 clusters
clusterer_8 = KMeans(n_clusters=8,n_init=10)
preds_kmeans_8 = clusterer_8.fit_predict(dato_quattour)
# 9 clusters
clusterer_9 = KMeans(n_clusters=9,n_init=10)
preds_kmeans_9 = clusterer_9.fit_predict(dato_quattour)

# %% [markdown]
# ### Implementación del Spectral Clustering para la cuarta base de datos

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# create spectral clustering object
spectral = SpectralClustering(n_clusters=3, affinity='rbf', gamma=1)

# fit and predict clusters
labels = spectral.fit_predict(dato_quattour)

# plot the clusters
plt.scatter(dato_quattour[:, 0], dato_quattour[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = SpectralClustering(n_clusters=n_clusters,affinity='rbf', gamma=1)
    preds = clusterer.fit_predict(dato_quattour)
    centers = spectral.fit_predict(dato_quattour) 

    score = silhouette_score (dato_quattour, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = SpectralClustering(n_clusters=5,assign_labels='discretize')
preds = clusterer.fit_predict(dato_quattour)

# %% [markdown]
# ### Implementación del DBSCAN para la cuarta base de datos

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto DBSCAN
dbscan = DBSCAN(eps=1, min_samples=4)

# Ajustar modelo DBSCAN a los datos
dbscan.fit(dato_quattour)

# Obtener las etiquetas de los clusters
labels = dbscan.labels_

# plot the clusters
plt.scatter(dato_quattour[:, 0], dato_quattour[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = DBSCAN(eps=1, min_samples=n_clusters)
    preds = clusterer.fit_predict(dato_quattour)
    centers = clusterer.labels_

    score = silhouette_score (dato_quattour, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = SpectralClustering(n_clusters=5,assign_labels='discretize')
preds = clusterer.fit_predict(dato_quattour)

# %% [markdown]
# ### Implementación del Gaussian Mixture Models para la cuarta base de datos

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto GaussianMixture
gmm = GaussianMixture(n_components=3)

# Ajustar modelo GaussianMixture a los datos
gmm.fit(dato_quattour)

# Obtener las etiquetas de los clusters
labels = gmm.predict(dato_quattour)

# plot the clusters
plt.scatter(dato_quattour[:, 0], dato_quattour[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = GaussianMixture(n_components=n_clusters)
    preds = clusterer.fit_predict(dato_quattour)
    centers = gmm.predict(dato_quattour)
    
    score = silhouette_score (dato_quattour, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = GaussianMixture(n_components=5)
preds = clusterer.fit_predict(dato_quattour)

# %% [markdown]
# # Quinta base de datos

# %%
data_quinque=sio.loadmat('/content/databases_opus_quattour/spiral.mat')
dato_quinque = data_quinque['spiral']

# %% [markdown]
# ### Implementación del Kmeans para la quinta base de datos

# %%
# Por defecto usa la distancia euclidiana
km = KMeans(
    n_clusters=3, init='random',
    n_init=10, random_state=0
)
y_km = km.fit_predict(dato_quinque)
# plot the clusters
plt.scatter(dato_quinque[:, 0], dato_quinque[:, 1], cmap='viridis', c=y_km)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato_quinque)
    centers = clusterer.cluster_centers_

    score = silhouette_score (dato_quinque, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
# 2 clusters
clusterer_2 = KMeans(n_clusters=2,n_init=10)
preds_kmeans_2 = clusterer_2.fit_predict(dato_quinque)
# 3 clusters
clusterer_3 = KMeans(n_clusters=3,n_init=10)
preds_kmeans_3 = clusterer_3.fit_predict(dato_quinque)
# 4 clusters
clusterer_4 = KMeans(n_clusters=4,n_init=10)
preds_kmeans_4 = clusterer_4.fit_predict(dato_quinque)
# 5 clusters
clusterer_5 = KMeans(n_clusters=5,n_init=10)
preds_kmeans_5 = clusterer_5.fit_predict(dato_quinque)
# 6 clusters
clusterer_6 = KMeans(n_clusters=6,n_init=10)
preds_kmeans_6 = clusterer_6.fit_predict(dato_quinque)
# 7 clusters
clusterer_7 = KMeans(n_clusters=7,n_init=10)
preds_kmeans_7 = clusterer_7.fit_predict(dato_quinque)
# 8 clusters
clusterer_8 = KMeans(n_clusters=8,n_init=10)
preds_kmeans_8 = clusterer_8.fit_predict(dato_quinque)
# 9 clusters
clusterer_9 = KMeans(n_clusters=9,n_init=10)
preds_kmeans_9 = clusterer_9.fit_predict(dato_quinque)

# %% [markdown]
# ### Implementación del Spectral Clustering para la quinta base de datos

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# create spectral clustering object
spectral = SpectralClustering(n_clusters=3, affinity='rbf', gamma=1)

# fit and predict clusters
labels = spectral.fit_predict(dato_quinque)

# plot the clusters
plt.scatter(dato_quinque[:, 0], dato_quinque[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = SpectralClustering(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato_quinque)
    centers = clusterer.labels_

    score = silhouette_score (dato_quinque, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = SpectralClustering(n_clusters=5,assign_labels='discretize')
preds = clusterer.fit_predict(dato_quinque)

# %% [markdown]
# ### Implementación del DBSCAN para la quinta base de datos

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto DBSCAN
dbscan = DBSCAN(eps=3, min_samples=5)

# Ajustar modelo DBSCAN a los datos
dbscan.fit(dato_quinque)

# Obtener las etiquetas de los clusters
labels = dbscan.labels_

# plot the clusters
plt.scatter(dato_quinque[:, 0], dato_quinque[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = DBSCAN(eps=3, min_samples=n_clusters)
    preds = clusterer.fit_predict(dato_quinque)
    centers = clusterer.labels_

    score = silhouette_score (dato_quinque, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %% [markdown]
# ### Implementación del Gaussian Mixture Models para la quinta base de datos

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto GaussianMixture
gmm = GaussianMixture(n_components=3)

# Ajustar modelo GaussianMixture a los datos
gmm.fit(dato_quinque)

# Obtener las etiquetas de los clusters
labels = gmm.predict(dato_quinque)

# plot the clusters
plt.scatter(dato_quinque[:, 0], dato_quinque[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = GaussianMixture(n_components=n_clusters)
    preds = clusterer.fit_predict(dato_quinque)
    centers = gmm.predict(dato_quinque)

    score = silhouette_score (dato_quinque, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = GaussianMixture(n_components=5)
preds = clusterer.fit_predict(dato_quinque)

# %% [markdown]
# # Sexta base de datos

# %%
from sklearn.preprocessing import MinMaxScaler
data_six=sio.loadmat('/content/databases_opus_quattour/unbalance.mat')
dato_six = data_six['unbalance']
scaler = MinMaxScaler()
scaler.fit(dato_six)
dato_six_scaled= scaler.transform(dato_six)

# %% [markdown]
# ### Implementación del Kmeans para la sexta base de datos

# %%
# Por defecto usa la distancia euclidiana
km = KMeans(
    n_clusters=8, init='random',
    n_init=10, random_state=0
)
y_km = km.fit_predict(dato_six_scaled)
# plot the clusters
plt.scatter(dato_six_scaled[:, 0], dato_six_scaled[:, 1], cmap='viridis',c=y_km)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato_six_scaled)
    centers = clusterer.cluster_centers_

    score = silhouette_score (dato_six_scaled, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
# 2 clusters
clusterer_2 = KMeans(n_clusters=2,n_init=10)
preds_kmeans_2 = clusterer_2.fit_predict(dato_six_scaled)
# 3 clusters
clusterer_3 = KMeans(n_clusters=3,n_init=10)
preds_kmeans_3 = clusterer_3.fit_predict(dato_six_scaled)
# 4 clusters
clusterer_4 = KMeans(n_clusters=4,n_init=10)
preds_kmeans_4 = clusterer_4.fit_predict(dato_six_scaled)
# 5 clusters
clusterer_5 = KMeans(n_clusters=5,n_init=10)
preds_kmeans_5 = clusterer_5.fit_predict(dato_six_scaled)
# 6 clusters
clusterer_6 = KMeans(n_clusters=6,n_init=10)
preds_kmeans_6 = clusterer_6.fit_predict(dato_six_scaled)
# 7 clusters
clusterer_7 = KMeans(n_clusters=7,n_init=10)
preds_kmeans_7 = clusterer_7.fit_predict(dato_six_scaled)
# 8 clusters
clusterer_8 = KMeans(n_clusters=8,n_init=10)
preds_kmeans_8 = clusterer_8.fit_predict(dato_six_scaled)
# 9 clusters
clusterer_9 = KMeans(n_clusters=9,n_init=10)
preds_kmeans_9 = clusterer_9.fit_predict(dato_six_scaled)

# %% [markdown]
# ### Implementación del Spectral Clustering para la sexta base de datos

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# create spectral clustering object
spectral = SpectralClustering(n_clusters=8)

# fit and predict clusters
labels = spectral.fit_predict(dato_six_scaled)

# plot the clusters
plt.scatter(dato_six_scaled[:, 0], dato_six_scaled[:, 1], c=labels, cmap='viridis')
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = SpectralClustering(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dato_six_scaled)

    score = silhouette_score (dato_six_scaled, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = SpectralClustering(n_clusters=5,assign_labels='discretize')
preds = clusterer.fit_predict(dato_six_scaled)

# %% [markdown]
# ### Implementación del DBSCAN para la sexta base de datos

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto DBSCAN
dbscan = DBSCAN(eps=0.05, min_samples=5)

# Ajustar modelo DBSCAN a los datos
dbscan.fit(dato_six_scaled)

# Obtener las etiquetas de los clusters
labels = dbscan.labels_

# plot the clusters
plt.scatter(dato_six_scaled[:, 0], dato_six_scaled[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(3, 10))

for n_clusters in list_k:
    clusterer = DBSCAN(eps=0.05, min_samples=n_clusters)
    preds = clusterer.fit_predict(dato_six_scaled)
    centers = clusterer.labels_

    score = silhouette_score (dato_six_scaled, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = DBSCAN(eps=2, min_samples=2)
preds = clusterer.fit_predict(dato_six_scaled)

# %% [markdown]
# ### Implementación del Gaussian Mixture Models para la sexta base de datos

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Crear objeto GaussianMixture
gmm = GaussianMixture(n_components=8)

# Ajustar modelo GaussianMixture a los datos
gmm.fit(dato_six_scaled)

# Obtener las etiquetas de los clusters
labels = gmm.predict(dato_six_scaled)

# plot the clusters
plt.scatter(dato_six_scaled[:, 0], dato_six_scaled[:, 1], c=labels)
plt.show()

# %%
from sklearn.metrics import silhouette_score

list_k = list(range(2, 10))

for n_clusters in list_k:
    clusterer = GaussianMixture(n_components=n_clusters)
    preds = clusterer.fit_predict(dato_six_scaled)
    centers = gmm.predict(dato_six_scaled)

    score = silhouette_score (dato_six_scaled, preds)
    print ("For n_clusters =" + str(n_clusters) + " silhouette score is " + str(score))

# %%
clusterer = GaussianMixture(n_components=5)
preds = clusterer.fit_predict(dato_six_scaled)
